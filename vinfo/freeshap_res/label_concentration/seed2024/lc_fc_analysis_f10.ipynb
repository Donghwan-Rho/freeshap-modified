# %% [markdown]
# # LC / FC Analysis — 수치 입력 틀
#
# - 고정: seed = 2024, `f = 10%` (selected data ratio)
# - 변동: `r ∈ {1, 5, 10, 15, 20, 25, 30}%` (eigen rank as % of `num_train_dp`)
# - 대상 데이터셋 (괄호 안은 `num_train_dp`, 그래프/표에 명시):
#   - `sst2` (5000), `qqp` (5000), `mnli` (5000), `ag_news` (5000), `mr` (5000)
#   - `mrpc` (3668), `rte` (2490)
# - 각 `(dataset, r)` 마다 accuracy / LC / FC 입력
# - 각 `r` 마다 cross-dataset Pearson / Spearman 상관계수 입력
#
# > 이 노트북은 **수치 입력용 스켈레톤**입니다. 분석/시각화 코드는 아직 포함하지 않습니다.
# >
# > 각 `# TODO` 옆에 `[type]` 을 표기했습니다:
# > - `[int]`  : ×10000 정수 하나 (예: `8234`)
# > - `[float]`: 스칼라 실수 하나 (예: `0.7123`)
# > - `[dict]` : 키가 고정된 dict (예: `{"LC": 0.x, "FC": 0.y, ...}`)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. 실험 설정 (Experiment Configuration)

# %%
SEED = 2024
F_PERCENT = 10  # selected data ratio (%)
R_VALUES = [1, 5, 10, 15, 20, 25, 30]  # eigen rank as % of num_train_dp

# dataset -> num_train_dp (그래프/표 label 용으로도 사용)
NUM_TRAIN_DP = {
    "sst2":    5000,
    "qqp":     5000,
    "mnli":    5000,
    "ag_news": 5000,
    "mr":      5000,
    "mrpc":    3668,
    "rte":     2490,
}
DATASETS = list(NUM_TRAIN_DP.keys())

# %% [markdown]
# ## 2. 데이터셋별 Base Accuracy 및 inv@f=10% Accuracy 입력
#
# - `acc_base`: `task_base_accuracy.py` 로 구한 inv-mode accuracy @ 0% selected (×10000 정수 그대로 넣기)
# - `acc_inv_f10`: `task_data_selection.py` inv-top 결과에서 f=10% 해당값 (×10000 정수)

# %%
# acc_base    : inv-mode accuracy @ 0% selected data (×10000 정수)
# acc_inv_f10 : inv-top accuracy @ f=10% selected data (×10000 정수)
ACC_BASE = {
    "sst2":    4908,  # TODO [int]
    "qqp":     6180,  # TODO [int]
    "mnli":    3490,  # TODO [int]
    "ag_news": 2470,  # TODO [int]
    "mr":      5020,  # TODO [int]
    "mrpc":    3162,  # TODO [int]
    "rte":     5271,  # TODO [int]
}

ACC_INV_f10 = {
    "sst2":    ,  # TODO [int]
    "qqp":     ,  # TODO [int]
    "mnli":    ,  # TODO [int]
    "ag_news": ,  # TODO [int]
    "mr":      ,  # TODO [int]
    "mrpc":    ,  # TODO [int]
    "rte":     ,  # TODO [int]
}

# %% [markdown]
# ## 3. `(dataset, r)` 별 Eigen@f=10% Accuracy / LC / FC 입력
#
# - `acc_eigen_f10`: `task_data_selection.py` eigen-top 결과에서 f=10% 해당값 (×10000 정수)
# - `LC` : rank-r label concentration (스칼라, 0~1)
# - `FC` : rank-r feature concentration (스칼라, 0~1)

# %%
# PER_RANK[ds][r] = {"acc_eigen_f10": int, "LC": float, "FC": float}
#   acc_eigen_f10 : ×10000 정수
#   LC, FC        : 스칼라 실수 (0~1 범위)
def _empty_rank_dict():
    return {r: {"acc_eigen_f10": None, "LC": None, "FC": None} for r in R_VALUES}

PER_RANK = {ds: _empty_rank_dict() for ds in DATASETS}

# ---- sst2 (num_train_dp = 5000) ----
PER_RANK["sst2"][1]  = {"acc_eigen_f10": , "LC": 4.7921424179e-01, "FC": 6.9836234446e-01}
PER_RANK["sst2"][5]  = {"acc_eigen_f10": , "LC": 5.6204644066e-01, "FC": 8.0785688474e-01}
PER_RANK["sst2"][10] = {"acc_eigen_f10": , "LC": 6.0746647126e-01, "FC": 8.5515145075e-01}
PER_RANK["sst2"][15] = {"acc_eigen_f10": , "LC": 6.4524631664e-01, "FC": 8.8292797056e-01}
PER_RANK["sst2"][20] = {"acc_eigen_f10": , "LC": 6.7428352773e-01, "FC": 9.0268771633e-01}
PER_RANK["sst2"][25] = {"acc_eigen_f10": , "LC": 7.0056079508e-01, "FC": 9.1799814756e-01}
PER_RANK["sst2"][30] = {"acc_eigen_f10": , "LC": 7.2608031388e-01, "FC": 9.3045000121e-01}

# ---- qqp (num_train_dp = 5000) ----
PER_RANK["qqp"][1]  = {"acc_eigen_f10": , "LC": 2.4614748848e-01, "FC": 8.6878348441e-01}
PER_RANK["qqp"][5]  = {"acc_eigen_f10": , "LC": 3.4712520430e-01, "FC": 9.2764119466e-01}
PER_RANK["qqp"][10] = {"acc_eigen_f10": , "LC": 4.0732254858e-01, "FC": 9.4961797579e-01}
PER_RANK["qqp"][15] = {"acc_eigen_f10": , "LC": 4.4650992558e-01, "FC": 9.6141052686e-01}
PER_RANK["qqp"][20] = {"acc_eigen_f10": , "LC": 4.8744118065e-01, "FC": 9.6925100019e-01}
PER_RANK["qqp"][25] = {"acc_eigen_f10": , "LC": 5.2381795966e-01, "FC": 9.7500270440e-01}
PER_RANK["qqp"][30] = {"acc_eigen_f10": , "LC": 5.5467490637e-01, "FC": 9.7945026135e-01}

# ---- mnli (num_train_dp = 5000) ----
PER_RANK["mnli"][1]  = {"acc_eigen_f10": , "LC": 1.5802771111e-01, "FC": 6.9532711206e-01}
PER_RANK["mnli"][5]  = {"acc_eigen_f10": , "LC": 2.4435483713e-01, "FC": 8.0738313024e-01}
PER_RANK["mnli"][10] = {"acc_eigen_f10": , "LC": 3.1304687800e-01, "FC": 8.5474453377e-01}
PER_RANK["mnli"][15] = {"acc_eigen_f10": , "LC": 3.6440521364e-01, "FC": 8.8238280589e-01}
PER_RANK["mnli"][20] = {"acc_eigen_f10": , "LC": 4.1419295666e-01, "FC": 9.0191755542e-01}
PER_RANK["mnli"][25] = {"acc_eigen_f10": , "LC": 4.5429350324e-01, "FC": 9.1695358061e-01}
PER_RANK["mnli"][30] = {"acc_eigen_f10": , "LC": 5.0325422357e-01, "FC": 9.2912288374e-01}


# ---- ag_news (num_train_dp = 5000) ----
PER_RANK["ag_news"][1]  = {"acc_eigen_f10": , "LC": 6.8370465951e-01, "FC": 7.7512707388e-01}
PER_RANK["ag_news"][5]  = {"acc_eigen_f10": , "LC": 7.4211392246e-01, "FC": 8.7223246087e-01}
PER_RANK["ag_news"][10] = {"acc_eigen_f10": , "LC": 7.7486542610e-01, "FC": 9.0799621966e-01}
PER_RANK["ag_news"][15] = {"acc_eigen_f10": , "LC": 8.0058780895e-01, "FC": 9.2689133874e-01}
PER_RANK["ag_news"][20] = {"acc_eigen_f10": , "LC": 8.2137785731e-01, "FC": 9.3952111906e-01}
PER_RANK["ag_news"][25] = {"acc_eigen_f10": , "LC": 8.3928547443e-01, "FC": 9.4897498113e-01}
PER_RANK["ag_news"][30] = {"acc_eigen_f10": , "LC": 8.5445121583e-01, "FC": 9.5650142741e-01}


# ---- mr (num_train_dp = 5000) ----
PER_RANK["mr"][1]  = {"acc_eigen_f10": , "LC": 4.3811941560e-01, "FC": 8.2473002344e-01}
PER_RANK["mr"][5]  = {"acc_eigen_f10": , "LC": 5.0310602719e-01, "FC": 8.9273479339e-01}
PER_RANK["mr"][10] = {"acc_eigen_f10": , "LC": 5.4627153966e-01, "FC": 9.2068778571e-01}
PER_RANK["mr"][15] = {"acc_eigen_f10": , "LC": 5.7965290481e-01, "FC": 9.3651766062e-01}
PER_RANK["mr"][20] = {"acc_eigen_f10": , "LC": 6.1200521746e-01, "FC": 9.4747286837e-01}
PER_RANK["mr"][25] = {"acc_eigen_f10": , "LC": 6.4134277673e-01, "FC": 9.5578671766e-01}
PER_RANK["mr"][30] = {"acc_eigen_f10": , "LC": 6.6880686631e-01, "FC": 9.6244920088e-01}


# ---- mrpc (num_train_dp = 3668) ----
PER_RANK["mrpc"][1]  = {"acc_eigen_f10": , "LC": 1.5026552511e-01, "FC": 6.8823466051e-01}
PER_RANK["mrpc"][5]  = {"acc_eigen_f10": , "LC": 2.4578324081e-01, "FC": 8.0058302299e-01}
PER_RANK["mrpc"][10] = {"acc_eigen_f10": , "LC": 3.1859074769e-01, "FC": 8.4828933902e-01}
PER_RANK["mrpc"][15] = {"acc_eigen_f10": , "LC": 3.7513619696e-01, "FC": 8.7667088924e-01}
PER_RANK["mrpc"][20] = {"acc_eigen_f10": , "LC": 4.2045146168e-01, "FC": 8.9693391889e-01}
PER_RANK["mrpc"][25] = {"acc_eigen_f10": , "LC": 4.6857955868e-01, "FC": 9.1268051397e-01}
PER_RANK["mrpc"][30] = {"acc_eigen_f10": , "LC": 5.0553843538e-01, "FC": 9.2550760899e-01}


# ---- rte (num_train_dp = 2490) ----
PER_RANK["rte"][1]  = {"acc_eigen_f10": , "LC": 4.4040915392e-02, "FC": 6.4113069254e-01}
PER_RANK["rte"][5]  = {"acc_eigen_f10": , "LC": 1.3512310032e-01, "FC": 7.6619982958e-01}
PER_RANK["rte"][10] = {"acc_eigen_f10": , "LC": 2.0620873570e-01, "FC": 8.2161796244e-01}
PER_RANK["rte"][15] = {"acc_eigen_f10": , "LC": 2.7114446302e-01, "FC": 8.5458455539e-01}
PER_RANK["rte"][20] = {"acc_eigen_f10": , "LC": 3.1542771359e-01, "FC": 8.7821360832e-01}
PER_RANK["rte"][25] = {"acc_eigen_f10": , "LC": 3.6050100738e-01, "FC": 8.9664371985e-01}
PER_RANK["rte"][30] = {"acc_eigen_f10": , "LC": 4.1286574906e-01, "FC": 9.1170739792e-01}

# %% [markdown]
# ## 4. 자동 분석 & 시각화
#
# - ER(r, f=10%) 정의 (Excess Retention): ER = (acc_eigen_f10(r) − acc_base) / (acc_inv_f10 − acc_base)
#   - 분자: eigen-r 근사가 chance(0%-selected) 대비 얼마나 inv 쪽으로 끌어올렸는지
#   - 분모: inv 가 chance(0%-selected) 대비 얼마나 개선되었는지
#   - ER=1 → eigen-r 이 inv 와 동일 정확도 (완전 보존), ER=0 → eigen-r 이 chance 수준
#   - ρ = 1 − ER 와 affine flip 관계라 corr 의 부호만 뒤집힘
# - 각 r 에서 7개 데이터셋에 걸쳐 Pearson/Spearman(ER, LC), Pearson/Spearman(ER, FC) 계산
# - 시각화: LC(r), FC(r), ER(r) per-dataset line plot + correlation-vs-r + scatter(ER vs LC/FC)

# %%
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr

# ------------------------------------------------------------------
# 1) Long-format DataFrame
#    ER (Excess Retention) = (acc_eigen - acc_base) / (acc_inv - acc_base)
#                          = 1 - rho
#    ER -> 1  : eigen accuracy ~ inv accuracy (perfect retention)
#    ER -> 0  : eigen accuracy ~ chance baseline
# ------------------------------------------------------------------
rows = []
for ds in DATASETS:
    acc_base = ACC_BASE[ds]
    acc_inv  = ACC_INV_f10[ds]
    for r in R_VALUES:
        entry = PER_RANK[ds][r]
        acc_e = entry["acc_eigen_f10"]
        lc    = entry["LC"]
        fc    = entry["FC"]
        denom = acc_inv - acc_base
        ER    = (acc_e - acc_base) / denom if denom != 0 else float("nan")
        rows.append({
            "dataset": ds, "num_train_dp": NUM_TRAIN_DP[ds], "r": r,
            "acc_base": acc_base, "acc_inv_f10": acc_inv,
            "acc_eigen_f10": acc_e, "LC": lc, "FC": fc, "ER": ER,
        })
df = pd.DataFrame(rows)

# ------------------------------------------------------------------
# 2) Cross-dataset correlations per r  (ER vs LC / FC)
# ------------------------------------------------------------------
CORR = {}
for r in R_VALUES:
    sub = df[df["r"] == r]
    p_lc, _ = pearsonr(sub["ER"],  sub["LC"])
    p_fc, _ = pearsonr(sub["ER"],  sub["FC"])
    s_lc, _ = spearmanr(sub["ER"], sub["LC"])
    s_fc, _ = spearmanr(sub["ER"], sub["FC"])
    CORR[r] = {"pearson_LC": p_lc, "pearson_FC": p_fc,
               "spearman_LC": s_lc, "spearman_FC": s_fc}
corr_df = pd.DataFrame(CORR).T.rename_axis("r").reset_index()

# ------------------------------------------------------------------
# 3) Print tables
# ------------------------------------------------------------------
print("=" * 72)
print("Per-(dataset, r) table")
print("=" * 72)
pivot_cols = ["acc_eigen_f10", "LC", "FC", "ER"]
for col in pivot_cols:
    print(f"\n[{col}]")
    print(df.pivot(index="dataset", columns="r", values=col)
            .reindex(DATASETS).round(4).to_string())

print("\n" + "=" * 72)
print("Cross-dataset correlations (ER vs LC / FC) per r")
print("=" * 72)
print(corr_df.round(4).to_string(index=False))

# ------------------------------------------------------------------
# 4) Plots (4-panel)
# ------------------------------------------------------------------
fig1, axes = plt.subplots(2, 2, figsize=(13, 9))

# (a) LC(r) per dataset
ax = axes[0, 0]
for ds in DATASETS:
    sub = df[df["dataset"] == ds].sort_values("r")
    ax.plot(sub["r"], sub["LC"], marker="o",
            label=f"{ds} (n={NUM_TRAIN_DP[ds]})")
ax.set_xlabel("rank r (%)"); ax.set_ylabel("LC(r)")
ax.set_title("Label Concentration vs r"); ax.grid(alpha=.3)
ax.legend(fontsize=8)

# (b) FC(r) per dataset
ax = axes[0, 1]
for ds in DATASETS:
    sub = df[df["dataset"] == ds].sort_values("r")
    ax.plot(sub["r"], sub["FC"], marker="o",
            label=f"{ds} (n={NUM_TRAIN_DP[ds]})")
ax.set_xlabel("rank r (%)"); ax.set_ylabel("FC(r)")
ax.set_title("Feature Concentration vs r"); ax.grid(alpha=.3)
ax.legend(fontsize=8)

# (c) ER(r) per dataset
ax = axes[1, 0]
for ds in DATASETS:
    sub = df[df["dataset"] == ds].sort_values("r")
    ax.plot(sub["r"], sub["ER"], marker="o",
            label=f"{ds} (n={NUM_TRAIN_DP[ds]})")
ax.axhline(1, color="k", lw=.8, ls="--")
ax.set_xlabel("rank r (%)"); ax.set_ylabel("ER(r, f=10%)")
ax.set_title("ER vs r"); ax.grid(alpha=.3)
ax.legend(fontsize=8)

# (d) Pearson/Spearman of (ER, LC) and (ER, FC) vs r
ax = axes[1, 1]
ax.plot(corr_df["r"], corr_df["pearson_LC"],  marker="o", label="Pearson(ER, LC)")
ax.plot(corr_df["r"], corr_df["pearson_FC"],  marker="s", label="Pearson(ER, FC)")
ax.plot(corr_df["r"], corr_df["spearman_LC"], marker="^", ls="--", label="Spearman(ER, LC)")
ax.plot(corr_df["r"], corr_df["spearman_FC"], marker="v", ls="--", label="Spearman(ER, FC)")
ax.axhline(0, color="k", lw=.8)
ax.set_xlabel("rank r (%)"); ax.set_ylabel("correlation")
ax.set_title("Cross-dataset correlation vs r")
ax.grid(alpha=.3); ax.legend(fontsize=8)

plt.tight_layout()
fig1.savefig("lc_fc_analysis_panel_f10.pdf", bbox_inches="tight")
fig1.savefig("lc_fc_analysis_panel_f10.png", bbox_inches="tight", dpi=200)
plt.show()

# ------------------------------------------------------------------
# 5) Scatter: ER vs LC / FC, colored by r
# ------------------------------------------------------------------
fig2, axes = plt.subplots(1, 2, figsize=(12, 5))
cmap = plt.get_cmap("viridis")
colors = {r: cmap(i / (len(R_VALUES) - 1)) for i, r in enumerate(R_VALUES)}
markers = ["o", "s", "^", "v", "D", "P", "X"]
marker_of = {ds: markers[i % len(markers)] for i, ds in enumerate(DATASETS)}

for xcol, ax, title in [("LC", axes[0], "ER vs LC"),
                        ("FC", axes[1], "ER vs FC")]:
    for r in R_VALUES:
        sub = df[df["r"] == r]
        for _, row in sub.iterrows():
            ax.scatter(row[xcol], row["ER"],
                       color=colors[r], marker=marker_of[row["dataset"]],
                       s=60, edgecolor="k", linewidth=.4)
    ax.set_xlabel(xcol); ax.set_ylabel("ER")
    ax.set_title(title); ax.grid(alpha=.3)
    ax.axhline(1, color="k", lw=.8, ls="--")

# shared legend
from matplotlib.lines import Line2D
r_handles  = [Line2D([0], [0], marker="o", color=colors[r], lw=0,
                     markersize=8, label=f"r={r}%") for r in R_VALUES]
ds_handles = [Line2D([0], [0], marker=marker_of[ds], color="gray", lw=0,
                     markersize=8, label=ds) for ds in DATASETS]
axes[0].legend(handles=r_handles,  loc="best", fontsize=8, title="rank")
axes[1].legend(handles=ds_handles, loc="best", fontsize=8, title="dataset")
plt.tight_layout()
fig2.savefig("lc_fc_scatter_f10.pdf", bbox_inches="tight")
fig2.savefig("lc_fc_scatter_f10.png", bbox_inches="tight", dpi=200)
plt.show()
